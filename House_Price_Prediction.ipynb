# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0        -122.23     37.88                41.0        880.0           129.0  \
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value
# 0           322.0       126.0         8.3252            452600.0  \
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0        -122.23     37.88                41.0        880.0           129.0  \
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value
# 0           322.0       126.0         8.3252            452600.0  \
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['median_house_value'],axis=1)

# %%
y=data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0        -122.23     37.88                41.0        880.0           129.0  \
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 6361     -117.97     34.13                33.0       2038.0           473.0  \
# 4957     -118.31     34.01                52.0       1793.0           350.0
# 16663    -120.67     35.29                44.0       2236.0           411.0
# 5370     -118.38     34.04                35.0       2237.0           592.0
# 3579     -118.54     34.23                35.0       3422.0           601.0
# ...          ...       ...                 ...          ...             ...
# 17291    -119.63     34.40                29.0       3865.0           814.0
# 12712    -121.40     38.59                18.0       2614.0           624.0
# 9418     -122.49     37.85                38.0        240.0            29.0
# 17093    -122.23     37.48                38.0       1578.0           399.0
# 4508     -118.19     34.05                41.0       1098.0           264.0
#
#        population  households  median_income ocean_proximity
# 6361       1546.0       469.0         3.4777          INLAND  \
# 4957       1303.0       366.0         3.0759       <1H OCEAN
# 16663      1036.0       437.0         3.0833      NEAR OCEAN
# 5370       1794.0       543.0         2.2961       <1H OCEAN
# 3579       1690.0       574.0         4.3750       <1H OCEAN
# ...           ...         ...            ...             ...
# 17291      1266.0       613.0         6.0069       <1H OCEAN
# 12712      1181.0       616.0         2.0432          INLAND
# 9418         63.0        34.0        12.2547        NEAR BAY
# 17093       879.0       388.0         2.7969      NEAR OCEAN
# 4508       1178.0       245.0         2.1058       <1H OCEAN
#
#        median_house_value
# 6361             144500.0
# 4957             123700.0
# 16663            219300.0
# 5370             207700.0
# 3579             232900.0
# ...                   ...
# 17291            500001.0
# 12712            156800.0
# 9418             500001.0
# 17093            298400.0
# 4508             124300.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7216
# INLAND        5211
# NEAR OCEAN    2082
# NEAR BAY      1833
# ISLAND           4
# Name: count, dtype: int64

# %%
encoded_data = encoded_data.astype(int)

# %%
print(train_data.head())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 6361     -117.97     34.13                33.0     2.154110        6.161207  \
# 4957     -118.31     34.01                52.0     2.139148        5.860786
# 16663    -120.67     35.29                44.0     2.164804        6.021023
# 5370     -118.38     34.04                35.0     2.164855        6.385194
# 3579     -118.54     34.23                35.0     2.212471        6.400257
#
#        population  households  median_income  median_house_value  <1H OCEAN
# 6361     7.344073       469.0         3.4777            144500.0          0  \
# 4957     7.173192       366.0         3.0759            123700.0          1
# 16663    6.944087       437.0         3.0833            219300.0          0
# 5370     7.492760       543.0         2.2961            207700.0          1
# 3579     7.433075       574.0         4.3750            232900.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 6361        1       0         0           0       2.860210         0.004593
# 4957        0       0         0           0       2.739775         0.005845
# 16663       0       0         0           1       2.781325         0.004954
# 5370        0       0         0           0       2.949479         0.003987
# 3579        0       0         0           0       2.892809         0.003854

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude" ,y="longitude",data=train_data, hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"]=train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_train,y_train = train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
X_train_s =scalar.fit_transform(X_train,)
reg = LinearRegression()
reg.fit(X_train_s,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
encoded_data = pd.get_dummies(test_data['ocean_proximity'])

encoded_data = encoded_data.astype(int)
test_data = test_data.join(encoded_data).drop(['ocean_proximity'], axis=1)
test_data["bedroom_ratio"]=test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms'] / test_data['households']
X_test = test_data.drop(['median_house_value'], axis=1)  # Features
y_test = test_data['median_house_value']

# %%
X_test_s = scalar.transform(X_test)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 6361     -117.97     34.13                33.0     2.154110        6.161207  \
# 4957     -118.31     34.01                52.0     2.139148        5.860786
# 16663    -120.67     35.29                44.0     2.164804        6.021023
# 5370     -118.38     34.04                35.0     2.164855        6.385194
# 3579     -118.54     34.23                35.0     2.212471        6.400257
# ...          ...       ...                 ...          ...             ...
# 17291    -119.63     34.40                29.0     2.225701        6.703188
# 12712    -121.40     38.59                18.0     2.182564        6.437752
# 9418     -122.49     37.85                38.0     1.869461        3.401197
# 17093    -122.23     37.48                38.0     2.124002        5.991465
# 4508     -118.19     34.05                41.0     2.079711        5.579730
#
#        population  households  median_income  median_house_value  <1H OCEAN
# 6361     7.344073       469.0         3.4777            144500.0          0  \
# 4957     7.173192       366.0         3.0759            123700.0          1
# 16663    6.944087       437.0         3.0833            219300.0          0
# 5370     7.492760       543.0         2.2961            207700.0          1
# 3579     7.433075       574.0         4.3750            232900.0          1
# ...           ...         ...            ...                 ...        ...
# 17291    7.144407       613.0         6.0069            500001.0          1
# 12712    7.074963       616.0         2.0432            156800.0          0
# 9418     4.158883        34.0        12.2547            500001.0          0
# 17093    6.779922       388.0         2.7969            298400.0          0
# 4508     7.072422       245.0         2.1058            124300.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 6361        1       0         0           0       2.860210         0.004593
# 4957        0       0         0           0       2.739775         0.005845
# 16663       0       0         0           1       2.781325         0.004954
# 5370        0       0         0           0       2.949479         0.003987
# 3579        0       0         0           0       2.892809         0.003854
# ...       ...     ...       ...         ...            ...              ...
# 17291       0       0         0           0       3.011719         0.003631
# 12712       1       0         0           0       2.949628         0.003543
# 9418        0       0         1           0       1.819347         0.054984
# 17093       0       0         0           1       2.820837         0.005474
# 4508        0       0         0           0       2.682935         0.008489
#
# [16346 rows x 16 columns]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 20262    -119.19     34.21                28.0     2.234483        6.699500  \
# 19535    -120.94     37.65                13.0     2.254684        6.886532
# 1094     -121.97     39.79                16.0     2.114093        5.703782
# 2108     -119.75     36.74                39.0     2.135611        5.863631
# 14028    -117.15     32.75                40.0     2.166078        6.363028
# ...          ...       ...                 ...          ...             ...
# 14316    -117.14     32.70                36.0     2.008489        5.003946
# 3189     -119.78     36.27                29.0     2.144148        5.755742
# 12817    -121.49     38.62                 8.0     2.364269        8.005367
# 11575    -118.00     33.77                28.0     2.172938        6.222576
# 18814    -121.45     41.04                33.0     2.153597        5.937536
#
#        population  households  median_income  median_house_value  <1H OCEAN
# 20262    7.846590       856.0         4.2227            235400.0          0  \
# 19535    8.017637       838.0         3.0577            119000.0          0
# 1094     6.807935       286.0         3.5735             89600.0          0
# 2108     7.002156       347.0         1.8958             51300.0          0
# 14028    6.806829       525.0         2.4650            198700.0          0
# ...           ...         ...            ...                 ...        ...
# 14316    6.324359       139.0         1.5729             82700.0          0
# 3189     6.972606       309.0         4.5714            100800.0          0
# 12817    8.917847      2885.0         3.9143            129700.0          0
# 11575    7.052721       456.0         3.5139            211700.0          1
# 18814    6.842683       343.0         2.6700             77500.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 20262       0       0         0           1       2.998233         0.002610
# 19535       1       0         0           0       3.054323         0.002691
# 1094        1       0         0           0       2.697980         0.007392
# 2108        1       0         0           0       2.745646         0.006154
# 14028       0       0         0           1       2.937580         0.004126
# ...       ...     ...       ...         ...            ...              ...
# 14316       0       0         0           1       2.491398         0.014450
# 3189        1       0         0           0       2.684397         0.006939
# 12817       1       0         0           0       3.385980         0.000820
# 11575       0       0         0           0       2.863669         0.004765
# 18814       1       0         0           0       2.757033         0.006279
#
# [4087 rows x 16 columns]

# %%
reg.score(X_test_s,y_test)
# Out:
# 0.667650281888551

# %%
from sklearn.ensemble import RandomForestRegressor
forest =RandomForestRegressor()
forest.fit(X_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_s,y_test)
# Out:
# 0.8290304831943873

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()
param_grid = {
    "n_estimators":[3,10,30],
    "max_features":[2,4,6,8]
}
grid_search =GridSearchCV(forest,param_grid,cv =5,scoring="neg_mean_squared_error",
                         return_train_score=True)
grid_search.fit(X_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest =grid_search.best_estimator_

# %%
best_forest.score(X_test_s,y_test)
# Out:
# 0.82835902598141
